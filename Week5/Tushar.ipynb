# %%
'''
1. State True or False : Python is platform independent programming language.
*
1 point
True
False
2. Python is a _______ language.   
*
1 point
Compiled
Interpreted
3. What is the output of the following code ?

arr = [ 1, 4, 5, 2, 3 ]
print( arr[-1] )
*
1 point
2
4
3
Runtime error
4. Which of the following is correct in python for the given variable ?  
 x = 1

Options :
I.      x += 1
II.     x++
III.    ++x
IV.    x = x + 1     
*
1 point
I and II
II and III
II and IV
I and IV
5. What will be the output of the following code ? 
 
 s = ""abdce""
 print ( s[ 2 : -1 ]"   
*
1 point
d
dc
dce
c
6. Which one is lexicographically greatest among the following ?   
*
1 point
1
10
20
2
7. What is the output for the following code?   

 def func(n):
          if n == 1 :
              return 2

          return n*func(n-1) // 2
 print(func(5))   
*
1 point
5
15
1
10
8. What is the output for the following code?     

 def func(s):

        if len(s) <= 1:
            return s

        return func(s[ 2 : ]) + s[0]
 print( func( ""AeI123"" ) )   
*
1 point
AeI123
21IA
2AI
2IA
9. What is the space complexity of the above code ?   
*
1 point
O(N)
O(log(N))
O(1)
None of these
10. What is the time complexity of the given function :  

 def func(arr , start, end) :

                  if start == end :

                        print( arr[ start ] );

                       return;

        mid = (start + end)//2;

        print( arr[mid] );

        func(arr, start, mid - 1 );
 
       func( arr, mid + 1, end );  
*
1 point
O(log(N))
O(N*log(N))
O(N)
None of these





Move Zeroes
Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.

Note that you must do this in-place without making a copy of the array.

Example 1:
Input: nums = [0,1,0,3,12]
Output: [1,3,12,0,0]

Example 2:
Input: nums = [0]
Output: [0]

Constraints:
a. 1 <= nums.length <= 10^4
b. -2^31 <= nums[i] <= 2^31 - 1

Note: Create a GitHub file for the solution and add the file link the the answer section below.

5 points
First Unique Character in a String

Given a string s, find the first non-repeating character in it and return its index. If it does not exist, return -1.

Example 1:
Input: s = "leetcode"
Output: 0

Example 2:
Input: s = "loveleetcode"
Output: 2

Example 3:
Input: s = "aabb"
Output: -1

Constraints:
a. 1 <= s.length <= 10^5
b. s consists of only lowercase English letters.

Note: Create a GitHub file for the solution and add the file link the the answer section below.



def func(s):

        if len(s) <= 1:
            return s

        return func(s[ 2 : ]) + s[0]
print( func( "AeI123") ) 


def func(n):
          if n == 1 :
              return 2

          return n*func(n-1) // 2
print(func(5))   

s = "abdce"
print ( s[ 2 : -1 ])
'''
